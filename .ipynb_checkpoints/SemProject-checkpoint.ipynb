# %%
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_lifestyle_performance_dataset-checkpoint.csv")
display(df)
# Out:
#      Age      Branch  Study_Hours_per_Day  Sleep_Hours  Screen_Time_Hours  \
# 0     23         ECE                 4.14         6.84               9.23
# 1     20       Civil                 5.97         5.52               3.09
# 2     24  Electrical                 3.19         3.39               5.02
# 3     21         CSE                 4.77         6.44               9.21
# 4     23       Civil                 5.42         6.54               4.76
# ..   ...         ...                  ...          ...                ...
# 995   24          IT                 4.60         5.26               4.23
# 996   17          IT                 4.02         6.55               3.88
# 997   25         CSE                 4.28         8.43               4.64
# 998   23       Civil                 6.42         6.06               4.84
# 999   19  Mechanical                 2.35         8.30               7.18
#
#      Gym_Hours_per_Week Diet_Type  Attendance_Percentage  \
# 0                  2.67   Non-Veg                  81.24
# 1                 15.61       Veg                  90.55
# 2                  2.52       Veg                  69.40
# 3                  0.00   Non-Veg                  80.79
# 4                  9.93       Veg                  82.63
# ..                  ...       ...                    ...
# 995               12.64   Non-Veg                  82.95
# 996                2.86   Non-Veg                  89.29
# 997                0.00       Veg                  74.57
# 998               10.08   Non-Veg                  91.57
# 999                1.91       Veg                  67.01
#
#      Stress_Level_1_to_10    Residence  Internal_Marks  CGPA
# 0                    4.93    Hosteller           65.86  7.52
# 1                    6.96  Day Scholar           62.52  7.21
# 2                    7.38    Hosteller           40.11  4.84
# 3                    5.84  Day Scholar           61.25  6.74
# 4                    6.67  Day Scholar           64.54  7.77
# ..                    ...          ...             ...   ...
# 995                  7.12  Day Scholar           69.63  6.65
# 996                  4.19    Hosteller           66.97  7.77
# 997                  2.80  Day Scholar           80.52  8.04
# 998                  6.76  Day Scholar           77.48  7.24
# 999                  1.22    Hosteller           68.44  7.89
#
# [1000 rows x 12 columns]

# %% [markdown]
# # Exploring University Students' Internal Marks

# %%
plt.hist(df["Internal_Marks"], rwidth=0.8)
plt.xlabel("Internal Marks")
plt.ylabel("Count")
plt.title("Histogram of Students' Internal Marks")
plt.show()

plt.boxplot(df["Internal_Marks"])
plt.ylabel("Internal Marks")
plt.title("Boxplot of Students' Internal Marks")
plt.show()

df["Internal_Marks"].describe()
# Out:
# count    1000.000000
# mean       65.922380
# std        10.123247
# min        35.000000
# 25%        59.330000
# 50%        65.600000
# 75%        72.547500
# max        93.930000
# Name: Internal_Marks, dtype: float64

# %% [markdown]
# Looking at the above plots it seems that internal marks are roughly normally distributed, which is what we would expect for a grade distribution. The histogram shows a bell curve shape, with the boxplot showing a very equal distribution above and below the mean with outliers on both ends.
#
# The data formatting this well could indicate some type of grade curving to cluster grades around a central mean, which in this case is about 65.9 with a SD of about 10.1.

# %% [markdown]
# # Calculating the Relationship Between Study Hours and CGPA

# %%
plt.scatter(df["Study_Hours_per_Day"], df["CGPA"])
plt.xlabel("Study Hours per Day")
plt.ylabel("CGPA")
plt.title("Study Hours per Day vs. CGPA")
plt.show()

r, p = stats.pearsonr(df["Study_Hours_per_Day"], df["CGPA"])
print("Pearson Correlation Coefficient: " + str(r))
print("P-Value: " + str(p))
# Out:
# Pearson Correlation Coefficient: 0.5066084567902694
# P-Value: 2.6375680323221514e-66

# %% [markdown]
# Based on the above values it can be concluded there is a statistically significant, moderately inscreasing relationship between a student's study hours per day and CGPA. In other words, increasing one's study hours per week can be expected to moderately increase CGPA.
